# %% [markdown]
# <a href="https://colab.research.google.com/github/UW-ERSL/AuTO/blob/main/compliantMechanism.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # run this first time to clone the directory 
# !git clone https://github.com/UW-ERSL/AuTO.git
# %cd AuTO/models

# %%
import numpy as np
import jax
import jax.numpy as jnp
from jax import jit, value_and_grad
import time
from utilfuncs import Mesher, computeLocalElements, computeFilter
from mmaOptimize import optimize
import matplotlib.pyplot as plt

# %%
nelx, nely = 40, 20;
elemSize = np.array([1., 1.])
mesh = {'nelx':nelx, 'nely':nely, 'elemSize':elemSize,\
        'ndof':2*(nelx+1)*(nely+1), 'numElems':nelx*nely}

# %%
material = {'Emax':1., 'Emin':1e-3, 'nu':0.3, 'penal':3.}

# %%
filterRadius = 1.5;
H, Hs = computeFilter(mesh, filterRadius)
ft = {'type':1, 'H':H, 'Hs':Hs}

# %%
# inverter
ndof = 2*(nelx+1)*(nely+1)
force = np.zeros((ndof,1))
forceOut = np.zeros((ndof,1))
dofs=np.arange(ndof)
nodeIn = 2*nely
nodeOut = 2*(nelx+1)*(nely+1)-2
fixed = dofs[np.r_[0:4:1,2*(nely+1)-1:2*(nelx+1)*(nely+1):2*(nely+1)]]
force[nodeIn, 0 ] = 1
forceOut[nodeOut, 0 ] = -1
free = np.setdiff1d(np.arange(ndof),fixed)
symXAxis = False
symYAxis = False
methodType = 'uOut' # 'uOut' # 'MSE_SE' # 'wMSE'
bc = {'nodeIn':nodeIn, 'nodeOut':nodeOut,\
      'force':force, 'forceOut':forceOut, 'fixed':fixed, 'free':free,\
      'symXAxis':symXAxis, 'symYAxis':symYAxis, 'methodType':methodType}

# %%
globalVolumeConstraint = {'isOn':True, 'vf':0.35}

# %%
optimizationParams = {'maxIters':200,'minIters':100,'relTol':0.02}

# %%
class CompliantMechanismTopOpt:
    def __init__(self, mesh, bc, material, globalvolCons):
        self.mesh = mesh
        self.material = material
        self.bc = bc
        M = Mesher()
        self.edofMat, self.idx = M.getMeshStructure(mesh)
        self.K0 = M.getK0(self.material)
        self.globalVolumeConstraint = globalvolCons
        self.objectiveHandle = jit(value_and_grad(self.computeObjective))
        self.consHandle = self.computeConstraints
        self.numConstraints = 1
        
    #-----------------------#
    # Code snippet 3.2
    def computeObjective(self, rho):
        @jit
        def MaterialModel(rho):
            E = self.material['Emin'] + \
                (self.material['Emax']-self.material['Emin'])*\
                               (rho+0.01)**self.material['penal'];
            return E
        #-----------------------#
        @jit
        # Code snippet 3.1
        def assembleKWithSprings(Y):
            K_asm = jnp.zeros((self.mesh['ndof'],)*2)
            K_elem = (self.K0.flatten()[np.newaxis]).T 
            K_elem = (K_elem*Y).T.flatten()
            K_asm = K_asm.at[(self.idx)].add(K_elem)
            # springs at input and output nodes
            K_asm = K_asm.at[(self.bc['nodeOut'],\
                                                  self.bc['nodeOut'])].add(0.1)
            K_asm = K_asm.at[(self.bc['nodeOut'],\
                                                  self.bc['nodeOut'])].add(0.1)
            return K_asm
        #-----------------------#
        @jit
        def solveKuf(K): 
            u_free = jax.scipy.linalg.solve\
                (K[self.bc['free'],:][:,self.bc['free']], \
                self.bc['force'][self.bc['free']], \
                 sym_pos = True, check_finite=False)
            u = jnp.zeros((self.mesh['ndof']))
            u = u.at[self.bc['free']].set(u_free.reshape(-1))
            return u
        #-----------------------#
        @jit
        def solve_dummy(K): 
            v_free = jax.scipy.linalg.solve\
                (K[self.bc['free'],:][:,self.bc['free']], \
                self.bc['forceOut'][self.bc['free']], \
                 sym_pos = True, check_finite=False)
            v = jnp.zeros((self.mesh['ndof']))
            v = v.at[self.bc['free']].set(v_free.reshape(-1))

            return v
        #-----------------------#
        E = MaterialModel(rho)
        K = assembleKWithSprings(E)
        u = solveKuf(K)
        # Code snippet 3.4
        if self.bc['methodType'] == 'uOut':
          J = u[self.bc['nodeOut']]
        elif self.bc['methodType'] == 'MSE_SE':
          v = solve_dummy(K)
          MSE = jnp.dot(v.T, jnp.dot(K,u))
          SE = jnp.dot(u.T, jnp.dot(K,u))
          J = -MSE/SE
        elif self.bc['methodType'] == 'wMSE':
          w = 0.9
          v = solve_dummy(K)
          MSE = jnp.dot(v.T, jnp.dot(K,u))
          SE = jnp.dot(u.T, jnp.dot(K,u))
          J = -w*MSE + (1 - w)*SE
        return J
    #-----------------------#
    def computeConstraints(self, rho, epoch): 
        @jit
        def computeGlobalVolumeConstraint(rho):
            vc = jnp.mean(rho)/self.globalVolumeConstraint['vf'] - 1.
            return vc
        c, gradc = value_and_grad(computeGlobalVolumeConstraint)\
                                    (rho)
        c, gradc = c.reshape((1,1)), gradc.reshape((1,-1))
        return c, gradc
    #-----------------------#
    def TO(self, optimizationParams, ft):
        optimize(self.mesh, optimizationParams, ft, \
             self.objectiveHandle, self.consHandle, self.numConstraints)

# %%
Opt = CompliantMechanismTopOpt(mesh, bc, material, \
                globalVolumeConstraint)
Opt.TO(optimizationParams, ft)
# Out:
# Iter 1; J 1.27; vf 0.80
# Iter 2; J 1.52; vf 0.60
# Iter 3; J 1.73; vf 0.40
# Iter 4; J 1.86; vf 0.30
# Iter 5; J 0.15; vf 0.29
# Iter 6; J -0.03; vf 0.29
# Iter 7; J -0.11; vf 0.27
# Iter 8; J -1.54; vf 0.30
# Iter 9; J -3.26; vf 0.30
# Iter 10; J -4.42; vf 0.32
# Iter 11; J -5.47; vf 0.33
# Iter 12; J -5.99; vf 0.33
# Iter 13; J -6.69; vf 0.33
# Iter 14; J -6.86; vf 0.34
# Iter 15; J -7.51; vf 0.34
# Iter 16; J -7.77; vf 0.34
# Iter 17; J -8.30; vf 0.34
# Iter 18; J -8.44; vf 0.34
# Iter 19; J -8.92; vf 0.34
# Iter 20; J -8.53; vf 0.34
# Iter 21; J -8.99; vf 0.34
# Iter 22; J -8.71; vf 0.34
# Iter 23; J -9.03; vf 0.34
# Iter 24; J -8.78; vf 0.34
# Iter 25; J -8.90; vf 0.34
# Iter 26; J -8.77; vf 0.34
# Iter 27; J -8.89; vf 0.34
# Iter 28; J -8.79; vf 0.34
# Iter 29; J -8.89; vf 0.34
# Iter 30; J -8.78; vf 0.34
# Iter 31; J -8.90; vf 0.34
# Iter 32; J -8.80; vf 0.34
# Iter 33; J -8.89; vf 0.34

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 3>()
#       1 Opt = CompliantMechanismTopOpt(mesh, bc, material, \
#       2                 globalVolumeConstraint)
# ----> 3 Opt.TO(optimizationParams, ft)
#
# Input In [11], in CompliantMechanismTopOpt.TO(self, optimizationParams, ft)
#      88 def TO(self, optimizationParams, ft):
# ---> 89     optimize(self.mesh, optimizationParams, ft, \
#      90          self.objectiveHandle, self.consHandle, self.numConstraints)
#
# File ~/Research/AuTO/models/mmaOptimize.py:40, in optimize(mesh, optimizationParams, ft, objectiveHandle, consHandle, numConstraints)
#      36 loop = loop + 1;
#      38 J, dJ = objectiveHandle(rho);
# ---> 40 vc, dvc = consHandle(rho, loop);
#      42 dJ, dvc = applySensitivityFilter(ft, rho, dJ, dvc)
#      44 J, dJ = J, dJ[np.newaxis].T
#
# Input In [11], in CompliantMechanismTopOpt.computeConstraints(self, rho, epoch)
#      81     vc = jnp.mean(rho)/self.globalVolumeConstraint['vf'] - 1.
#      82     return vc
# ---> 83 c, gradc = value_and_grad(computeGlobalVolumeConstraint)\
#      84                             (rho)
#      85 c, gradc = c.reshape((1,1)), gradc.reshape((1,-1))
#      86 return c, gradc
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/_src/api.py:1001, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     999 _check_scalar(ans)
#    1000 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# -> 1001 g = vjp_py(lax_internal._one(ans))
#    1002 g = g[0] if isinstance(argnums, int) else g
#    1003 if not has_aux:
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/_src/tree_util.py:287, in _HashableCallableShim.__call__(self, *args, **kw)
#     286 def __call__(self, *args, **kw):
# --> 287   return self.fun(*args, **kw)
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/_src/api.py:2364, in _vjp_pullback_wrapper(cotangent_dtypes, cotangent_shapes, io_tree, fun, py_args)
#    2359   if np.shape(arg) != ct_shape:
#    2360     raise ValueError(
#    2361         f"Shape of cotangent input to vjp pullback function {np.shape(arg)} "
#    2362         "must be the same as the shape of corresponding primal input "
#    2363         f"{ct_shape}.")
# -> 2364 ans = fun(*args)
#    2365 return tree_unflatten(out_tree, ans)
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/_src/tree_util.py:287, in _HashableCallableShim.__call__(self, *args, **kw)
#     286 def __call__(self, *args, **kw):
# --> 287   return self.fun(*args, **kw)
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/interpreters/ad.py:137, in vjp.<locals>.unbound_vjp(pvals, jaxpr, consts, *cts)
#     135 cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#     136 dummy_args = [UndefinedPrimal(v.aval) for v in jaxpr.invars]
# --> 137 arg_cts = backward_pass(jaxpr, reduce_axes, True, consts, dummy_args, cts)
#     138 return map(instantiate_zeros, arg_cts)
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/interpreters/ad.py:232, in backward_pass(jaxpr, reduce_axes, transform_stack, consts, primals_in, cotangents_in)
#     230   params = dict(eqn.params)
#     231   call_jaxpr = params.pop('call_jaxpr')
# --> 232   cts_out = get_primitive_transpose(eqn.primitive)(
#     233       params, call_jaxpr, invals, cts_in, cts_in_avals, reduce_axes)
#     234 elif eqn.primitive in reducing_transposes:
#     235   cts_out = reducing_transposes[eqn.primitive](
#     236       reduce_axes, cts_in, *invals, **eqn.params)
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/interpreters/ad.py:605, in call_transpose(primitive, params, call_jaxpr, args, ct, _, reduce_axes)
#     603   in_type = [(core.raise_to_shaped(core.get_aval(x)), True) for x in all_args]
#     604   fun = lu.annotate(fun, tuple(in_type))
# --> 605 out_flat = primitive.bind(fun, *all_args, **params)
#     606 return tree_unflatten(out_tree(), out_flat)
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/core.py:1765, in CallPrimitive.bind(self, fun, *args, **params)
#    1764 def bind(self, fun, *args, **params):
# -> 1765   return call_bind(self, fun, *args, **params)
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/core.py:1781, in call_bind(primitive, fun, *args, **params)
#    1779 tracers = map(top_trace.full_raise, args)
#    1780 fun_ = lu.annotate(fun_, fun.in_type)
# -> 1781 outs = top_trace.process_call(primitive, fun_, tracers, params)
#    1782 return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/core.py:678, in EvalTrace.process_call(self, primitive, f, tracers, params)
#     677 def process_call(self, primitive, f, tracers, params):
# --> 678   return primitive.impl(f, *tracers, **params)
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/_src/dispatch.py:182, in _xla_call_impl(***failed resolving arguments***)
#     180 if fun.in_type is not None:
#     181   arg_specs = [(None, *xs) for _, *xs in arg_specs]
# --> 182 compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
#     183                              keep_unused, *arg_specs)
#     184 try:
#     185   return compiled_fun(*args)
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/linear_util.py:285, in cache.<locals>.memoized_fun(fun, *args)
#     283   fun.populate_stores(stores)
#     284 else:
# --> 285   ans = call(fun, *args)
#     286   cache[key] = (ans, fun.stores)
#     288 thread_local.most_recent_entry = weakref.ref(ans)
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/_src/dispatch.py:230, in _xla_callable_uncached(fun, device, backend, name, donated_invars, keep_unused, *arg_specs)
#     228 def _xla_callable_uncached(fun: lu.WrappedFun, device, backend, name,
#     229                            donated_invars, keep_unused, *arg_specs):
# --> 230   return lower_xla_callable(fun, device, backend, name, donated_invars, False,
#     231                             keep_unused, *arg_specs).compile().unsafe_call
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/_src/dispatch.py:704, in XlaComputation.compile(self)
#     701     self._executable = XlaCompiledComputation.from_trivial_jaxpr(
#     702         **self.compile_args)
#     703   else:
# --> 704     self._executable = XlaCompiledComputation.from_xla_computation(
#     705         self.name, self._hlo, self._explicit_args, **self.compile_args)
#     707 return self._executable
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/_src/dispatch.py:806, in XlaCompiledComputation.from_xla_computation(name, xla_computation, explicit_args, nreps, device, backend, tuple_args, in_avals, out_avals, effects, kept_var_idx, keepalive)
#     803 options.parameter_is_tupled_arguments = tuple_args
#     804 with log_elapsed_time(f"Finished XLA compilation of {name} "
#     805                       "in {elapsed_time} sec"):
# --> 806   compiled = compile_or_get_cached(backend, xla_computation, options)
#     807 buffer_counts = (None if len(out_avals) == 1 and not config.jax_dynamic_shapes
#     808                  else [aval_to_num_buffers(aval) for aval in out_avals])
#     809 if effects:
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/_src/dispatch.py:768, in compile_or_get_cached(backend, computation, compile_options)
#     766     ir_str = computation
#     767   _dump_ir_to_file(module_name, ir_str)
# --> 768 return backend_compile(backend, computation, compile_options)
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/_src/profiler.py:206, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     203 @wraps(func)
#     204 def wrapper(*args, **kwargs):
#     205   with TraceAnnotation(name, **decorator_kwargs):
# --> 206     return func(*args, **kwargs)
#     207   return wrapper
#
# File ~/anaconda3/envs/jaxenv2/lib/python3.8/site-packages/jax/_src/dispatch.py:713, in backend_compile(backend, built_c, options)
#     709 @profiler.annotate_function
#     710 def backend_compile(backend, built_c, options):
#     711   # we use a separate function call to ensure that XLA compilation appears
#     712   # separately in Python profiling results
# --> 713   return backend.compile(built_c, compile_options=options)
#
# KeyboardInterrupt:
